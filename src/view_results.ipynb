# %%
import pandas as pd
from scripts.testing.helper_functions import *

# %%
full_output_file = '../outputs/test-results-GaMS-2B-Instruct-v6-4096-MERGED-eval-scores.csv'

# %%
df = pd.read_csv(full_output_file)

# %%
# df.round(3)

# %%
print("           average  median")
for col in df.columns[3:]:
    print(f"{col:<10}| {column_average_score(df, column_name=col):.3f} | {column_median_score(df, column_name=col):.3f}")
# Out:
#            average  median
# GPT sem   | 1.289 | 1.000
# GPT read  | 2.957 | 3.000
# LaBSE p   | 0.706 | 0.708
# LaBSE     | 0.772 | 0.796
# NE F1     | 0.280 | 0.267
# NE P      | 0.293 | 0.261
# NE R      | 0.317 | 0.300
# BS F1     | 0.903 | 0.904
# BS P      | 0.904 | 0.909
# BS R      | 0.904 | 0.904
# Len diff  | 0.489 | 0.333

# %%
plot_column_distribution(df, column_name='GPT sem', bins=4)

# %%
plot_column_distribution(df, column_name='LaBSE p', bins=10)

# %%
plot_column_distribution(df, column_name='LaBSE', bins=10)

# %%
plot_column_distribution(df, column_name='BS F1', bins=10)

# %%
plot_column_distribution(df, column_name='NE R', bins=10)

# %%
plot_correlation_matrix(df)

# %%
thresholds = {'LaBSE': 0.9, 'NE F1': 0.7}
print_reports(df, indices=find_reports_based_on_criteria(df, thresholds=thresholds, n=5), metric='LaBSE p')
# Out:
# metric: LaBSE p, n: 5
# ---------------------------------------------------------
# Score: 0.710726261138916, Index: 146
# Podatki o prometu.
#
#  Na štajerski avtocesti proti Mariboru je zaradi pokvarjenega tovornjaka oviran promet med priključkoma Šempeter in Žalec.
#
#  Zaradi močnega vetra je primorska avtocesta zaprta med priključkoma Kastelec in Kozina proti Ljubljani. Obvoz je po vzporedni regionalni cesti med Kastelcem in Kozino.
#
#  Prav tako zaradi burje je na vipavski hitri cesti med razcepom Nanos in priključkom Selo prepovedan promet za hladilnike in vozila s ponjavami, lažja od 8 ton.
# --------
#
#
#  Podatki o prometu.
#
#  Zaradi pokvarjenega vozila je promet oviran na štajerski avtocesti med Šempetrom in Žalcem proti Mariboru ter na primorski avtocesti proti Ljubljani na uvozu Postojna.
#
#  Na primorski avtocesti proti Ljubljani je zaradi burje zaprt predor Kastelec. Obvoz je po vzporedni regionalni cesti med priključkoma Kastelec in Kozina.
#
# ...

# %%
print_reports(df, indices=find_n_reports(df, n=5, column_name='GPT sem', sort='desc'), metric='GPT sem')
# Out:
# metric: GPT sem, n: 5
# ---------------------------------------------------------
# Score: 3, Index: 119
# Podatki o prometu.
#
#  Na štajerski avtocesti proti Ljubljani je zaradi pokvarjenega vozila promet oviran med priključkoma Šentrupert in Vransko.
#
#  Zaradi pokvarjenega vozila je promet oviran tudi na dolenjski avtocesti med priključkoma Mirna Peč in Novo mesto-zahod proti Obrežju.
#
#  Na cesti Col-Črni Vrh-Godovič je prepovedan promet za tovorna vozila s priklopniki in polpriklopnike.
#
#  Cesta čez prelaz Vršič je prevozna samo za osebna vozila z verigami.
# --------
#
#
#  Podatki o prometu.
#
#  Na regionalni cesti Col-Črni Vrh-Godovič je prepovedan promet za tovorna vozila s priklopniki in za polpriklopnike.
#
#  Cesta čez prelaz Vršič je prevozna samo za osebna vozila z verigami.
#
#
#
# ---------------------------------------------------------
# Score: 3, Index: 168
# Podatki o prometu.
#
# ...

# %%
print_reports(df, indices=find_n_reports(df, n=5, column_name='LaBSE p', sort='desc'), metric='LaBSE p')
# Out:
# metric: LaBSE p, n: 5
# ---------------------------------------------------------
# Score: 1.0000001192092896, Index: 86
# Podatki o prometu.
#
#  Na štajerski avtocesti proti Ljubljani je zaradi pokvarjenega vozila promet oviran med priključkoma Šentrupert in Vransko.
#
#  Na primorski avtocesti proti Ljubljani je zaradi del zaprt vozni pas med priključkoma Kozina in Divača.
#
#  Do 22-ih velja omejitev prometa tovornih vozil, katerih največja dovoljena masa presega 7 ton in pol.
# --------
#
#
#  Podatki o prometu.
#
#  Do 22-ih velja omejitev prometa tovornih vozil, katerih največja dovoljena masa presega 7 ton in pol.
#
#
#
# ---------------------------------------------------------
# Score: 0.9999998807907104, Index: 179
# Podatki o prometu.
#
#  Na primorski avtocesti je zaradi pokvarjenega tovornjaka oviran promet med priključkom Brezovica in razcepom Kozarje proti Ljubljani.
#
#  Cesta čez prelaz Vršič je prevozna samo za osebna vozila z verigami.
# --------
#
#
# ...

# %%
print_reports(df, indices=find_n_reports(df, n=2, column_name='LaBSE', sort='desc'), metric='LaBSE')
# Out:
# metric: LaBSE, n: 2
# ---------------------------------------------------------
# Score: 0.9271453619003296, Index: 228
# Podatki o prometu.
#
#  Na štajerski avtocesti proti Ljubljani je zaradi prometne nesreče zaprt prehitevalni pas med priključkoma Celje-vzhod in Celje-center.
#
#  Zaradi del je na primorski avtocesti oviran promet med priključkoma Brezovica in Vrhnika v obe smeri.
# --------
#
#
#  Podatki o prometu.
#
#  Na štajerski avtocesti med priključkoma Celje-vzhod in Celje-center proti Ljubljani je zaradi nesreče oviran promet.
#
#  Okvarjeno vozilo ovira promet na primorski avtocesti med Vrhniko in Logatcem proti Kopru.
#
#
#
#
#
# ---------------------------------------------------------
# Score: 0.921958863735199, Index: 159
# Podatki o prometu.
#
#  Zaradi burje je primorska avtocesta zaprta med priključkoma Kastelec in Kozina proti Ljubljani. Obvoz je po vzporedni regionalni cesti med obema priključkoma.
#
# ...

# %%
print_reports(df, indices=find_n_reports(df, n=3, column_name='BS F1', sort='desc'), metric='BS F1')
# Out:
# metric: BS F1, n: 3
# ---------------------------------------------------------
# Score: 0.9547942876815796, Index: 169
# Podatki o prometu.
#
#  Zaradi burje je na vipavski hitri cesti med Selom in razcepom Nanos prepovedan promet za hladilnike in vozila s ponjavami, lažja od 8 ton.
#
#  Na cesti Col-Črni Vrh-Godovič je prepovedan promet za tovorna vozila s priklopniki in polpriklopnike.
#
#  Cesta čez prelaz Vršič je prevozna samo za osebna vozila z verigami.
#
#
# --------
#
#
#  Podatki o prometu.
#
#  Na vipavski hitri cesti je zaradi pokvarjenega vozila oviran promet med Selom in Ajdovščino proti Ljubljani.
#
#  Na regionalni cesti Col-Črni Vrh-Godovič je prepovedan promet za tovorna vozila s priklopniki in polpriklopnike.
#
#  Cesta čez prelaz Vršič je prevozna samo za osebna vozila z verigami.
#
#
#
# ---------------------------------------------------------
# Score: 0.9525744915008544, Index: 130
# Podatki o prometu.
#
# ...

# %%
print_reports(df, indices=find_n_reports(df, n=3, column_name='NE F1', sort='desc'), metric='NE F1')
# Out:
# metric: NE F1, n: 3
# ---------------------------------------------------------
# Score: 0.8, Index: 168
# Podatki o prometu.
#
#  Zaradi burje je na primorski avtocesti med priključkoma Kastelec in Kozina v obe smeri prepovedan promet za počitniške prikolice, hladilnike in vozila s ponjavami.
#
#  Na cesti Col-Črni Vrh-Godovič je prepovedan promet za tovorna vozila s priklopniki in za polpriklopnike.
#
#  Cesta čez prelaz Vršič je prevozna samo za osebna vozila z verigami.
# --------
#
#
#  Podatki o prometu.
#
#  Na regionalni cesti Col-Črni Vrh-Godovič je prepovedan promet za tovorna vozila s priklopniki in polpriklopnike.
#
#  Cesta čez prelaz Vršič je prevozna samo za osebna vozila z verigami.
#
#  Primorska avtocesta proti Ljubljani je med priključkoma Kastelec in Kozina spet prevozna.
#
#
#
# ---------------------------------------------------------
# Score: 0.75, Index: 145
# Podatki o prometu.
#
# ...
